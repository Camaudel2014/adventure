# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Carlos Delgado

# %% [markdown]
# **Staff Accountant)

# %% [markdown]
# _I am interested in Data Science to continue my knowledge in technology

# %% [markdown]
# ### Suppossed to perform a mathematical exercise

# %%
1 + 1
# Out:
# 2

# %%
1 Statistics
2 Accounting
3 Algebra
